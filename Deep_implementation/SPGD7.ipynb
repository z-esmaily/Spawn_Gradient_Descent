# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install progress
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9613 sha256=34fbccb47d3d8496cad08d223867b6975d2fe9839763cc989798e1fed03a4979
#   Stored in directory: /root/.cache/pip/wheels/a2/68/5f/c339b20a41659d856c93ccdce6a33095493eb82c3964aac5a1
# Successfully built progress
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.1 MB/s eta 0:00:00
# ...

# %%
# %cd '/content/drive/MyDrive/SPGD/'
# Out:
# /content/drive/MyDrive/SPGD

# %%
# !python cifar_BestAcc_Compare_AccandTime.py --arch densenet --depth 19 --epochs 76 --checkpoint 'checkpoint/densenet'
# Out:
# ==> Preparing dataset cifar10
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ==> creating model 'densenet'
#     Total params: 0.04M
#
# Training with SGD
# /content/drive/MyDrive/SPGD/cifar_BestAcc_Compare_AccandTime.py:404: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs, targets = torch.autograd.Variable(inputs, volatile=True), torch.autograd.Variable(targets)
# ...

# %%
# !python fashion_BestAcc_Compare_AccandTime.py --arch resnet --depth 20 --epochs 81 --checkpoint 'checkpoint/resnet'
# Out:
# ==> Preparing dataset fashionmnist
# ...
# 100% 26.4M/26.4M [00:03<00:00, 7.68MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 29.5k/29.5k [00:00<00:00, 165kB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 4.42M/4.42M [00:01<00:00, 3.11MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 5.15k/5.15k [00:00<00:00, 28.6MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
